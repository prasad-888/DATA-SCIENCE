# %% [markdown]
# ### PLOT TYPES

# %%
import pandas as pd
df2 = pd.read_csv(r"C:\Users\Prasad\Downloads\data\data\df2")
df1 = pd.read_csv(r"C:\Users\Prasad\Downloads\data\data\df1")

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df1
# Out:
#      Unnamed: 0         A         B         C         D
# 0    2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1    2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2    2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3    2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4    2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ..          ...       ...       ...       ...       ...
# 995  2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 996  2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 997  2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 998  2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 999  2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.DataFrame(index =['Ankur','Pranav','Vivek','Raksha','Shyam'],
                 data={'Apples':[20, 10, 40, 20, 50],
                      'Oranges': [35, 40, 25, 19, 33]})
df
# Out:
#         Apples  Oranges
# Ankur       20       35
# Pranav      10       40
# Vivek       40       25
# Raksha      20       19
# Shyam       50       33

# %%
df2.plot.area()
plt.show()

# %%
df2.plot.area(alpha=0.2)
plt.show()

# %%
df.plot.barh()
plt.show()

# %%
df2.plot.bar()
plt.show()

# %%
df2.plot.bar(stacked=True)
plt.show()

# %%
df.plot.hist(bins=100, alpha=0.2)
plt.show()

# %%
df1.plot.line()
plt.show()

# %%
df1.plot.line(y='B', figsize=(12,3))
plt.show()

# %%
df1.plot.line(y="B", figsize=(12,3), lw=1)
plt.show()

# %%
df1.plot.scatter(x='A',y='B')
plt.show()

# %%
df1.plot.scatter(x='A',y='B',c='C')
plt.show()

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
plt.show()

# %%
df1.plot.scatter(x='A',y='B',c='C', s=df1['C'])
plt.show()
# Out:
# C:\Users\Prasad\anaconda3\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.scatter(x="A",y="B",c='C',s=df1['C']*200)
plt.show()
# Out:
# C:\Users\Prasad\anaconda3\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.scatter(x='A',y='B',c='C',s=df1['C']*200, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\Prasad\anaconda3\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()
plt.show()

# %%
df2.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.460880   0.352935   0.587008   0.631597
# std     0.340793   0.301272   0.284332   0.258158
# min     0.039762   0.008948   0.103423   0.190008
# 25%     0.212334   0.179302   0.427949   0.457694
# 50%     0.371366   0.240298   0.555036   0.584144
# 75%     0.753558   0.515799   0.873619   0.837267
# max     0.937288   0.997075   0.907307   0.977680

# %%
np.random.randn(1000,2)
# Out:
# array([[-0.70471579,  0.52593177],
#        [ 1.62380796,  1.80733421],
#        [ 0.15865582, -0.45265371],
#        ...,
#        [ 0.93736308, -1.44296261],
#        [-0.41906418,  0.18172905],
#        [ 0.31314174,  0.2918251 ]])

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df
# Out:
#             a         b
# 0   -0.162383 -0.889945
# 1   -0.131067  0.935373
# 2   -0.703945  1.233714
# 3    1.367099 -0.409404
# 4   -1.082916  0.657829
# ..        ...       ...
# 995  0.428426 -0.813636
# 996 -0.105610 -0.910528
# 997  0.214570  1.151258
# 998 -1.583919  1.177993
# 999 -0.687137 -0.798754
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a',y='b')
plt.show()

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
plt.show()

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')
plt.show()

# %%
df2['a'].plot.kde()
plt.show()

# %%
df2.plot.kde()
plt.show()
