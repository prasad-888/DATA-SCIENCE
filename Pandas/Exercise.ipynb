# %%
import pandas as pd
so = pd.read_csv(r"C:\Users\Prasad\Downloads\data\data\stackoverflow_qa.csv")
so
# Out:
#              id         creationdate  score  viewcount  \
# 0       5486226  2011-03-30 12:26:50      4       2113
# 1       5515021  2011-04-01 14:50:44      8       7015
# 2       5558607  2011-04-05 21:13:50      2       7392
# 3       6467832  2011-06-24 12:31:45      9      13056
# 4       7577546  2011-09-28 01:58:38      9       2488
# ...         ...                  ...    ...        ...
# 56393  47606711  2017-12-02 10:07:13      0         17
# 56394  47607549  2017-12-02 11:41:59     -1         41
# 56395  47609325  2017-12-02 15:16:26      0         33
# 56396  47609598  2017-12-02 15:45:40      2         18
# 56397  47611969  2017-12-02 19:59:09     -6         19
#
#                                                    title  answercount  \
# 0                               Rolling median in python            3
# 1           Compute a compounded return series in Python            3
# 2            Sort a pandas DataMatrix in ascending order            2
# ...

# %%
employee = pd.read_csv(r"C:\Users\Prasad\Downloads\data\data\employee.csv")
employee.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# ...

# %% [markdown]
# ## Exercise 1: Find all the questions that have exactly 5 answers.

# %%
 so.loc[so['answercount'] ==5]
# Out:
#              id         creationdate  score  viewcount  \
# 75     10373660  2012-04-29 16:10:35    199     207980
# 115    10791661  2012-05-29 00:06:52      7      12210
# 130    10972410  2012-06-10 21:12:43     19      46428
# 189    11391969  2012-07-09 09:04:33     44      27467
# 246    11811392  2012-08-04 19:25:34     17      20051
# ...         ...                  ...    ...        ...
# 53433  47028601  2017-10-31 05:45:19      2         38
# 53752  46557074  2017-10-04 04:33:51      0         61
# 53983  46882557  2017-10-23 05:36:29      3         87
# 54384  47542980  2017-11-29 00:05:31      2         43
# 55444  47213771  2017-11-10 00:13:38      1        247
#
#                                                    title  answercount  \
# 75       Converting a Pandas GroupBy object to DataFrame            5
# 115    How do I discretize values in a pandas DataFra...            5
# 130           pandas: combine two columns in a DataFrame            5
# ...

# %% [markdown]
# ## Exercise 2: Find all the questions that have less than 10 views.

# %%
so.loc[so['viewcount']<10]
# Out:
#              id         creationdate  score  viewcount  \
# 7787   26493306  2014-10-21 18:06:10      1          6
# 17653  33641540  2015-11-10 23:19:36      0          9
# 29414  40062672  2016-10-15 18:24:21     -1          9
# 36086  42538091  2017-03-01 17:20:37      0          9
# 36340  42080039  2017-02-07 01:13:30      0          8
# 40490  43271693  2017-04-07 07:04:19      0          9
# 43489  45069021  2017-07-12 23:22:49      1          9
# 47371  45212468  2017-07-20 10:43:55      0          9
# 49232  45890470  2017-08-25 23:16:57      0          7
# 50461  45991431  2017-08-31 23:26:20      0          9
# 52518  47091256  2017-11-03 08:20:58      0          8
# 53794  46628996  2017-10-08 08:22:26      0          7
# 54304  47208273  2017-11-09 17:38:49      0          6
# 54462  47254707  2017-11-12 22:26:52      0          9
# 54507  47611836  2017-12-02 19:44:00      0          8
# 54855  47126567  2017-11-05 20:58:17      0          9
# ...

# %% [markdown]
# ## Exercise 3: Find all the questions where the person asking it is the same as the person answering it.

# %%
so.loc[so['quest_name'] == so['ans_name']]
# Out:
#              id         creationdate  score  viewcount  \
# 10      8273092  2011-11-25 18:39:02      1       2333
# 33      9721429  2012-03-15 14:08:31      9       5732
# 58     10020591  2012-04-04 23:17:23     21      20171
# 68     10175068  2012-04-16 13:27:44     15       7501
# 74     10264739  2012-04-22 02:35:06      9       2362
# ...         ...                  ...    ...        ...
# 55767  47419823  2017-11-21 18:06:38      0         35
# 55777  47350412  2017-11-17 12:12:51      0         40
# 55781  47170051  2017-11-08 01:21:47      1        100
# 55987  47134254  2017-11-06 10:01:27      0         62
# 56175  47354844  2017-11-17 16:10:26      0         48
#
#                                                    title  answercount  \
# 10                         python: pandas install errors            2
# 33     How do I read a fix width format text file in ...            4
# 58     How to resample a dataframe with different fun...            4
# ...

# %% [markdown]
# ## Exercise 4: Find all the questions that don’t have an accepted answer (ans_name is NaN) but have a score of more than 100

# %%
so.loc[(so['ans_name'].isnull()) & (so['score']> 100)]
# Out:
#             id         creationdate  score  viewcount  \
# 184   11350770  2012-07-05 18:57:34    149     155776
# 514   13148429  2012-10-30 22:22:59    312     228357
# 527   13187778  2012-11-02 00:57:33    102     202329
# 560   13331698  2012-11-11 13:48:53    154     174964
# 5013  19377969  2013-10-15 09:42:52    128     144045
# 5370  20845213  2013-12-30 18:24:25    130      61332
# 8289  26266362  2014-10-08 21:00:19    132     108655
#
#                                                   title  answercount  \
# 184       pandas + dataframe - select by partial string            7
# 514       How to change the order of DataFrame columns?           19
# 527   Convert pandas dataframe to numpy array, prese...            8
# 560   How to apply a function to two columns of Pand...            9
# 5013  Combine two columns of text in dataframe in pa...           10
# 5370  How to avoid Python/Pandas creating an index i...            3
# ...

# %% [markdown]
# ## Exercise 5: Find all the questions where the reputation of the person asking is higher than that of the person answering. Then, calculate the percentage of times this happens.

# %%
so.loc[(so['quest_rep'] > so['ans_rep']),'id'].count()/len(so)  * 100
# Out:
# 3.9717720486542074

# %% [markdown]
# ## Exercise 6: Find all questions where the number of answers is between 5 and 10 (inclusive) and the number of views is less than 1,000.

# %%
so.loc[ (so['answercount'].between(1,10)) & (so['viewcount']<1000)]
# Out:
#              id         creationdate  score  viewcount  \
# 5       7766400  2011-10-14 10:33:54      2        977
# 9       8270129  2011-11-25 13:55:02      1        891
# 13      8914992  2012-01-18 18:00:16      4        961
# 21      9421412  2012-02-23 21:14:19      2        892
# 30      9647656  2012-03-10 15:35:26      3        986
# ...         ...                  ...    ...        ...
# 56392  47610316  2017-12-02 17:02:03      1         23
# 56393  47606711  2017-12-02 10:07:13      0         17
# 56394  47607549  2017-12-02 11:41:59     -1         41
# 56395  47609325  2017-12-02 15:16:26      0         33
# 56396  47609598  2017-12-02 15:45:40      2         18
#
#                                                    title  answercount  \
# 5                Pandas + Django + mod_wsgi + virtualenv            1
# 9                       Pandas Panel for share portfolio            1
# 13     indexing several csv files with pandas from re...            1
# ...

# %% [markdown]
# ## Exercise 7: Find the inverse of Exercise 6. Verify your results by adding the rows of both returned Series to check if it matches the number of rows in the original DataFrame.

# %%
42054 + 14344
# Out:
# 56398

# %%
so.loc[ ~((so['answercount'].between(1,10)) & (so['viewcount']<1000))].count()
# Out:
# id               14344
# creationdate     14344
# score            14344
# viewcount        14344
# title            14344
# answercount      14344
# commentcount     14344
# favoritecount     5592
# quest_name       14295
# quest_rep        14296
# ans_name          6585
# ans_rep           6585
# dtype: int64

# %% [markdown]
# ## Exercise 8: Find all Black or African American females working in the “Houston Police Department-HPD.”

# %%
employee.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# ...

# %%
employee.loc[(employee['RACE']=='Black or African American') & (employee['GENDER']=='Female') & (employee["DEPARTMENT"] == "Houston Police Department-HPD")]
# Out:
#       UNIQUE_ID             POSITION_TITLE                     DEPARTMENT  \
# 55           55   ADMINISTRATIVE ASSOCIATE  Houston Police Department-HPD
# 113         113      SENIOR POLICE OFFICER  Houston Police Department-HPD
# 137         137             JAIL ATTENDANT  Houston Police Department-HPD
# 196         196      SENIOR POLICE OFFICER  Houston Police Department-HPD
# 228         228      FINANCIAL ANALYST III  Houston Police Department-HPD
# ...         ...                        ...                            ...
# 1940       1940      SENIOR POLICE OFFICER  Houston Police Department-HPD
# 1949       1949             POLICE OFFICER  Houston Police Department-HPD
# 1955       1955             JAIL ATTENDANT  Houston Police Department-HPD
# 1964       1964  ADMINISTRATIVE SPECIALIST  Houston Police Department-HPD
# 1978       1978     POLICE SERVICE OFFICER  Houston Police Department-HPD
#
#       BASE_SALARY                       RACE EMPLOYMENT_TYPE  GENDER  \
# ...

# %% [markdown]
# ## Exercise 9: Find females with a salary over 100,000 OR males with a salary under 50,000.

# %%
employee.loc[(employee['BASE_SALARY'] > 100000) | ((employee['GENDER']=="Male")& (employee["BASE_SALARY"]<50000))]
# Out:
#       UNIQUE_ID                            POSITION_TITLE  \
# 0             0               ASSISTANT DIRECTOR (EX LVL)
# 2             2                            POLICE OFFICER
# 7             7                                 CARPENTER
# 8             8  DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV
# 9             9            AIRPORT OPERATIONS COORDINATOR
# ...         ...                                       ...
# 1989       1989                          EQUIPMENT WORKER
# 1992       1992                          SECURITY OFFICER
# 1994       1994                            POLICE CAPTAIN
# 1995       1995                            POLICE OFFICER
# 1997       1997                            POLICE OFFICER
#
#                           DEPARTMENT  BASE_SALARY                       RACE  \
# 0        Municipal Courts Department     121862.0            Hispanic/Latino
# 2      Houston Police Department-HPD      45279.0                      White
# ...

# %% [markdown]
# ## Exercise 10: Find females in the following departments with a salary over 60,000: “Parks & Recreation,” “Solid Waste Management,” “Fleet Management Department,” and “Library.”

# %%
employee.loc[(employee["DEPARTMENT"].isin(["Parks & Recreation", "Solid Waste Management", "Fleet Management Department", "Library"]))& (employee["GENDER"]=="Female") & (employee["BASE_SALARY"]>60000)]
# Out:
#       UNIQUE_ID                            POSITION_TITLE  \
# 249         249                             STAFF ANALYST
# 412         412                ADMINISTRATIVE COORDINATOR
# 476         476                 ADMINISTRATIVE SUPERVISOR
# 892         892                             LIBRARIAN III
# 1165       1165  DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV
# 1484       1484    SENIOR STAFF ANALYST (EXECUTIVE LEVEL)
#
#                   DEPARTMENT  BASE_SALARY                       RACE  \
# 249   Solid Waste Management      75041.0            Hispanic/Latino
# 412                  Library      79302.0            Hispanic/Latino
# 476                  Library      60632.0  Black or African American
# 892                  Library      61454.0                      White
# 1165                 Library     107763.0  Black or African American
# 1484      Parks & Recreation      83916.0            Hispanic/Latino
#
#      EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE
# ...

# %% [markdown]
# ## Exercise 11: Find all males with a salary over 100,000. Return only the columns Race, Gender, and Salary.

# %%
con1 = (employee['BASE_SALARY']>100000)
con2 = employee.loc[con1,['RACE',"GENDER","BASE_SALARY"]]


con2
# Out:
#                            RACE  GENDER  BASE_SALARY
# 0               Hispanic/Latino  Female     121862.0
# 8                         White    Male     107962.0
# 11    Black or African American    Male     180416.0
# 43              Hispanic/Latino    Male     165216.0
# 66                        White  Female     100791.0
# 169                       White    Male     120916.0
# 178                       White    Male     210588.0
# 186                       White    Male     110881.0
# 217      Asian/Pacific Islander    Male     102019.0
# 237      Asian/Pacific Islander  Female     130416.0
# 297                       White    Male     141948.0
# 299   Black or African American    Male     100228.0
# 366                       White  Female     110000.0
# 416                       White    Male     104455.0
# 522   Black or African American  Female     110686.0
# 561                       White    Male     125884.0
# 591                       White  Female     105503.0
# ...

# %% [markdown]
# ## Exercise 12: Select all salaries as a Series in a separate variable. From this Series, select all salaries under 25,000.

# %%
sal=employee["BASE_SALARY"] < 25000
sal
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: BASE_SALARY, Length: 2000, dtype: bool

# %%
employee[sal]
# Out:
#      UNIQUE_ID POSITION_TITLE                     DEPARTMENT  BASE_SALARY  \
# 454        454  CAR ATTENDANT  Houston Police Department-HPD      24960.0
#
#                           RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 454  Black or African American       Full Time  Female            Active
#
#       HIRE_DATE    JOB_DATE
# 454  2016-01-19  2016-01-19

# %% [markdown]
# ## Exercise 13: Get the same result as Exercise 12, but make your selection directly from the employee DataFrame in a single line of code.

# %%
employee.loc[employee['BASE_SALARY']<25000]
# Out:
#      UNIQUE_ID POSITION_TITLE                     DEPARTMENT  BASE_SALARY  \
# 454        454  CAR ATTENDANT  Houston Police Department-HPD      24960.0
#
#                           RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 454  Black or African American       Full Time  Female            Active
#
#       HIRE_DATE    JOB_DATE
# 454  2016-01-19  2016-01-19
