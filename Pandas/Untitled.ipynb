# %%
import pandas as pd
import numpy as np


df = pd.read_csv(r"C:\Users\Prasad\Downloads\data\data\employee_sample.csv", index_col =0)
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY
# Tom         Male  White         Engineering                23  107962
# Niko        Male  Black         Engineering                 1   30347
# Penelope  Female  White         Engineering                12   60258
# Aria      Female  Black         Engineering                 8   43618
# Sofia     Female  Black  Parks & Recreation                23   26125
# Dean        Male  Black  Parks & Recreation                 3   33592
# Zach        Male  White  Parks & Recreation                 4   37565

# %%
df['SCORE']=99

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99

# %%
df['BONUS']=40

# %%
df['TOTAL_COMPENSATION'] = df['SALARY'] + df['BONUS']

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS  TOTAL_COMPENSATION
# Tom          40              108002
# Niko         40               30387
# Penelope     40               60298
# Aria         40               43658
# Sofia        40               26165
# Dean         40               33632
# Zach         40               37605

# %%
df['BONUS_RATE']= [.2, .1, 0, .15, .12, .3, 0.5]

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS  TOTAL_COMPENSATION  BONUS_RATE
# Tom          40              108002        0.20
# Niko         40               30387        0.10
# Penelope     40               60298        0.00
# Aria         40               43658        0.15
# Sofia        40               26165        0.12
# Dean         40               33632        0.30
# Zach         40               37605        0.50

# %%
floor = np.random.randint(low=1, high=10, size=len(df))

# %%
floor
# Out:
# array([2, 9, 8, 1, 1, 6, 8])

# %%
df['FLOOR'] = floor

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS  TOTAL_COMPENSATION  BONUS_RATE  FLOOR
# Tom          40              108002        0.20      2
# Niko         40               30387        0.10      9
# Penelope     40               60298        0.00      8
# Aria         40               43658        0.15      1
# Sofia        40               26165        0.12      1
# Dean         40               33632        0.30      6
# Zach         40               37605        0.50      8

# %%
last_name = pd.Series(['Smith', 'Jones','Williams','Green','Brown','Simpson','Peters'])

# %%
df['last_name']= last_name

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS  TOTAL_COMPENSATION  BONUS_RATE  FLOOR last_name
# Tom          40              108002        0.20      2       NaN
# Niko         40               30387        0.10      9       NaN
# Penelope     40               60298        0.00      8       NaN
# Aria         40               43658        0.15      1       NaN
# Sofia        40               26165        0.12      1       NaN
# Dean         40               33632        0.30      6       NaN
# Zach         40               37605        0.50      8       NaN

# %%
print(last_name.index)
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
print(df.index)
# Out:
# Index(['Tom', 'Niko', 'Penelope', 'Aria', 'Sofia', 'Dean', 'Zach'], dtype='object')

# %%
last_name.index = df.index[:len(last_name)]

# %%
df['LAST NAME'] = last_name

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS  TOTAL_COMPENSATION  BONUS_RATE  FLOOR last_name LAST NAME
# Tom          40              108002        0.20      2       NaN     Smith
# Niko         40               30387        0.10      9       NaN     Jones
# Penelope     40               60298        0.00      8       NaN  Williams
# Aria         40               43658        0.15      1       NaN     Green
# Sofia        40               26165        0.12      1       NaN     Brown
# Dean         40               33632        0.30      6       NaN   Simpson
# Zach         40               37605        0.50      8       NaN    Peters

# %%
df['BONUS_RATE']*df['SALARY']
# Out:
# Tom         21592.4
# Niko         3034.7
# Penelope        0.0
# Aria         6542.7
# Sofia        3135.0
# Dean        10077.6
# Zach        18782.5
# dtype: float64

# %%
df['BONUS'] = df['BONUS_RATE']*df['SALARY']

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#             BONUS  TOTAL_COMPENSATION  BONUS_RATE  FLOOR last_name LAST NAME
# Tom       21592.4              108002        0.20      2       NaN     Smith
# Niko       3034.7               30387        0.10      9       NaN     Jones
# Penelope      0.0               60298        0.00      8       NaN  Williams
# Aria       6542.7               43658        0.15      1       NaN     Green
# Sofia      3135.0               26165        0.12      1       NaN     Brown
# Dean      10077.6               33632        0.30      6       NaN   Simpson
# Zach      18782.5               37605        0.50      8       NaN    Peters

# %%
df['BONUS']=df['BONUS'].astype(int)

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS  TOTAL_COMPENSATION  BONUS_RATE  FLOOR last_name LAST NAME
# Tom       21592              108002        0.20      2       NaN     Smith
# Niko       3034               30387        0.10      9       NaN     Jones
# Penelope      0               60298        0.00      8       NaN  Williams
# Aria       6542               43658        0.15      1       NaN     Green
# Sofia      3135               26165        0.12      1       NaN     Brown
# Dean      10077               33632        0.30      6       NaN   Simpson
# Zach      18782               37605        0.50      8       NaN    Peters

# %%
df.loc[['Niko','Penelope','Aria'],['FLOOR']]
# Out:
#           FLOOR
# Niko          9
# Penelope      8
# Aria          1

# %%
df.loc[['Niko','Penelope','Aria'],['FLOOR']]=[3, 6, 4]

# %%
df.loc[['Niko','Penelope','Aria'], ['FLOOR']]
# Out:
#           FLOOR
# Niko          3
# Penelope      6
# Aria          4

# %%
df_selected = df[['GENDER','YEARS EXPERIENCE','SCORE']].copy()

# %%
df_selected.loc[df_selected['YEARS EXPERIENCE']>20, 'SCORE']=100

# %%
df_selected
# Out:
#           GENDER  YEARS EXPERIENCE  SCORE
# Tom         Male                23    100
# Niko        Male                 1     99
# Penelope  Female                12     99
# Aria      Female                 8     99
# Sofia     Female                23    100
# Dean        Male                 3     99
# Zach        Male                 4     99

# %%
df_org = df.copy()
df.loc[:,'FLOOR']=33
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS  TOTAL_COMPENSATION  BONUS_RATE  FLOOR last_name LAST NAME
# Tom       21592              108002        0.20     33       NaN     Smith
# Niko       3034               30387        0.10     33       NaN     Jones
# Penelope      0               60298        0.00     33       NaN  Williams
# Aria       6542               43658        0.15     33       NaN     Green
# Sofia      3135               26165        0.12     33       NaN     Brown
# Dean      10077               33632        0.30     33       NaN   Simpson
# Zach      18782               37605        0.50     33       NaN    Peters

# %%
df.iloc[:,9]=22

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS  TOTAL_COMPENSATION  BONUS_RATE  FLOOR last_name LAST NAME
# Tom       21592              108002        0.20     22       NaN     Smith
# Niko       3034               30387        0.10     22       NaN     Jones
# Penelope      0               60298        0.00     22       NaN  Williams
# Aria       6542               43658        0.15     22       NaN     Green
# Sofia      3135               26165        0.12     22       NaN     Brown
# Dean      10077               33632        0.30     22       NaN   Simpson
# Zach      18782               37605        0.50     22       NaN    Peters

# %%
df.loc[df['DEPARTMENT']=='Engineering', 'BONUS']
# Out:
# Tom         21592
# Niko         3034
# Penelope        0
# Aria         6542
# Name: BONUS, dtype: int32

# %%
df.loc[df['DEPARTMENT']=='Engineering','BONUS'] += 5000

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS  TOTAL_COMPENSATION  BONUS_RATE  FLOOR last_name LAST NAME
# Tom       26592              108002        0.20     22       NaN     Smith
# Niko       8034               30387        0.10     22       NaN     Jones
# Penelope   5000               60298        0.00     22       NaN  Williams
# Aria      11542               43658        0.15     22       NaN     Green
# Sofia      3135               26165        0.12     22       NaN     Brown
# Dean      10077               33632        0.30     22       NaN   Simpson
# Zach      18782               37605        0.50     22       NaN    Peters

# %%
white_male = (df["GENDER"]=='Male') & (df['RACE']=='White')
black_female = (df['GENDER']=='Female') & (df['RACE']=='Black')

criteria = white_male | black_female

# %%
df[criteria]
# Out:
#        GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom      Male  White         Engineering                23  107962     99
# Aria   Female  Black         Engineering                 8   43618     99
# Sofia  Female  Black  Parks & Recreation                23   26125     99
# Zach     Male  White  Parks & Recreation                 4   37565     99
#
#        BONUS  TOTAL_COMPENSATION  BONUS_RATE  FLOOR last_name LAST NAME
# Tom    26592              108002        0.20     22       NaN     Smith
# Aria   11542               43658        0.15     22       NaN     Green
# Sofia   3135               26165        0.12     22       NaN     Brown
# Zach   18782               37605        0.50     22       NaN    Peters

# %%
df.loc[criteria, 'SCORE'] -= 10

# %%
df[criteria]
# Out:
#        GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom      Male  White         Engineering                23  107962     89
# Aria   Female  Black         Engineering                 8   43618     89
# Sofia  Female  Black  Parks & Recreation                23   26125     89
# Zach     Male  White  Parks & Recreation                 4   37565     89
#
#        BONUS  TOTAL_COMPENSATION  BONUS_RATE  FLOOR last_name LAST NAME
# Tom    26592              108002        0.20     22       NaN     Smith
# Aria   11542               43658        0.15     22       NaN     Green
# Sofia   3135               26165        0.12     22       NaN     Brown
# Zach   18782               37605        0.50     22       NaN    Peters

# %%
s =df['SALARY'].copy()
s
# Out:
# Tom         107962
# Niko         30347
# Penelope     60258
# Aria         43618
# Sofia        26125
# Dean         33592
# Zach         37565
# Name: SALARY, dtype: int64

# %%
s.loc[['Tom', 'Sofia','Zach']] = [99999, 39999, 49999]

# %%
s
# Out:
# Tom         99999
# Niko        30347
# Penelope    60258
# Aria        43618
# Sofia       39999
# Dean        33592
# Zach        49999
# Name: SALARY, dtype: int64

# %%
s.iloc[[0, 4, 6]] = [40000, 40000, 40000]

# %%
s
# Out:
# Tom         40000
# Niko        30347
# Penelope    60258
# Aria        43618
# Sofia       40000
# Dean        33592
# Zach        40000
# Name: SALARY, dtype: int64

# %%
s_org =s.copy()

# %%
s[s< 40000] *=2

# %%
s
# Out:
# Tom         40000
# Niko        60694
# Penelope    60258
# Aria        43618
# Sofia       40000
# Dean        67184
# Zach        40000
# Name: SALARY, dtype: int64
