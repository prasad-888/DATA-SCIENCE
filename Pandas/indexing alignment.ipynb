# %%
import pandas as pd
import numpy as np

so = pd.read_csv(r"C:\Users\Prasad\Downloads\data\data\stackoverflow_qa.csv")
so_head = so.head()

s = pd.Series([False, False, True, True, True])


print("Boolean Series Index:")
print(s.index)

print("\\nDataFrame Index:")
print(so_head.index)
# Out:
# Boolean Series Index:
# RangeIndex(start=0, stop=5, step=1)
# \nDataFrame Index:
# RangeIndex(start=0, stop=5, step=1)

# %%
so_head[s]
# Out:
#         id         creationdate  score  viewcount  \
# 2  5558607  2011-04-05 21:13:50      2       7392
# 3  6467832  2011-06-24 12:31:45      9      13056
# 4  7577546  2011-09-28 01:58:38      9       2488
#
#                                                title  answercount  \
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount      quest_name  quest_rep      ans_name  \
# 2             0            1.0  Jason Strimpel     3301.0  Wes McKinney
# 3             0            7.0      user814005      117.0  Wes McKinney
# 4             0            5.0    Uri Laserson      958.0          HYRY
#
#    ans_rep
# 2  43310.0
# 3  43310.0
# 4  54137.0

# %%
so_head.set_index('id', inplace=True)

print("Boolean Series Index:")
print(s.index)

print("\\nDataFrame Index:")
print(so_head.index)

so_head[s]
# Out:
# Boolean Series Index:
# RangeIndex(start=0, stop=5, step=1)
# \nDataFrame Index:
# Index([5486226, 5515021, 5558607, 6467832, 7577546], dtype='int64', name='id')
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_19704\1588556397.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   so_head[s]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[27], line 9
#       6 print("\\nDataFrame Index:")
#       7 print(so_head.index)
# ----> 9 so_head[s]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
# ...

# %%
so_head
# Out:
#                 creationdate  score  viewcount  \
# id
# 5486226  2011-03-30 12:26:50      4       2113
# 5515021  2011-04-01 14:50:44      8       7015
# 5558607  2011-04-05 21:13:50      2       7392
# 6467832  2011-06-24 12:31:45      9      13056
# 7577546  2011-09-28 01:58:38      9       2488
#
#                                                      title  answercount  \
# id
# 5486226                           Rolling median in python            3
# 5515021       Compute a compounded return series in Python            3
# 5558607        Sort a pandas DataMatrix in ascending order            2
# 6467832  How to get the correlation between two timeser...            1
# 7577546  Using pandas, how do I subsample a large DataF...            1
#
#          commentcount  favoritecount      quest_name  quest_rep  \
# id
# 5486226             4            1.0         yueerhu      125.0
# 5515021             6            7.0  Jason Strimpel     3301.0
# ...

# %%
s
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
s_condition = so_head['score']>5
so_head[s_condition]
# Out:
#                 creationdate  score  viewcount  \
# id
# 5515021  2011-04-01 14:50:44      8       7015
# 6467832  2011-06-24 12:31:45      9      13056
# 7577546  2011-09-28 01:58:38      9       2488
#
#                                                      title  answercount  \
# id
# 5515021       Compute a compounded return series in Python            3
# 6467832  How to get the correlation between two timeser...            1
# 7577546  Using pandas, how do I subsample a large DataF...            1
#
#          commentcount  favoritecount      quest_name  quest_rep  \
# id
# 5515021             6            7.0  Jason Strimpel     3301.0
# 6467832             0            7.0      user814005      117.0
# 7577546             0            5.0    Uri Laserson      958.0
#
#                 ans_name  ans_rep
# id
# 5515021  Mike Pennington  26995.0
# 6467832     Wes McKinney  43310.0
# 7577546             HYRY  54137.0
