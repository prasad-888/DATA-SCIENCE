# %% [raw]
# Questionnaire
# Which type of plots can be used to check the distribution of data?
# What is the difference between a bar plot and a count plot?
# Which plot method is used to plot the correlation between columns?
# What happens in spine removal?
# Seaborn Exercise
# Exercise 1: Create a boxplot to visualize the distribution of the total_bill for each day of the week from the tips dataset.
# Exercise 2: Use a scatterplot to visualize the relationship between total_bill and tip from the tips dataset. Customize the plot with different markers and colors.
# Exercise 3: Create a pairplot to explore the relationships between numerical columns in the iris dataset. Use different colors based on the species column.
# Exercise 4: Plot a heatmap to display the correlation between the numerical columns in the tips dataset. Customize the colors using a suitable colormap and add annotations.
# Exercise 5: Create a violinplot to visualize the distribution of total_bill for each day of the week in the tips dataset. Split the data by the sex column and use the Set1 color palette.
# You can now proceed with answering and exploring these exercises!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Exercise 1: Create a boxplot to visualize the distribution of the total_bill for each day of the week from the tips dataset.

sns.kdeplot(tips[['day','total_bill']])
plt.show()

# %%
## Exercise 2: Use a scatterplot to visualize the relationship between total_bill and tip from the tips dataset. 
## Customize the plot with different markers and colors.

sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex')
plt.show()

# %%
## Exercise 3: Create a pairplot to explore the relationships between numerical columns in the iris dataset.
## Use different colors based on the species column.

iris = sns.load_dataset('iris')
sns.pairplot(data=tips, hue='time', palette='coolwarm')
plt.show()

# %%
### Exercise 4: Plot a heatmap to display the correlation between the numerical columns in the tips dataset.
### Customize the colors using a suitable colormap and add annotations.

sns.heatmap(tips[['total_bill','tip','size']].corr(), cmap='Set1', annot=True)
plt.show()

# %%
## Exercise 5: Create a violinplot to visualize the distribution of total_bill for each day of the week in the tips dataset. 
## Split the data by the sex column and use the Set1 color palette.

sns.violinplot(x='day',y='total_bill',hue='sex',palette='Set1',data=tips)
plt.show()
